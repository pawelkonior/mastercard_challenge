# %% [markdown]
# ## Goal
#
# The objective of this notebook is to construct meaningful and predictive features from the cleaned transactional, user, and merchant datasets. These features will be used for downstream modeling tasks such as fraud detection. The process includes:
#
# - Merging relevant data sources
# - Extracting temporal and behavioral signals
# - Encoding categorical variables
# - Creating domain-informed ratios and transformations
# - Scaling numerical variables
# - Saving the processed dataset for modeling

# %%
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler

# %%
sns.set_style("whitegrid")
plt.rcParams["figure.figsize"] = (12, 6)

DATA_PROCESSED_DIR = Path("../data/processed")
DATA_INTERIM_DIR = Path("../data/interim")

# %%
transactions = pd.read_parquet(DATA_INTERIM_DIR / "transaction_locations_dropped.parquet")
users = pd.read_parquet(DATA_INTERIM_DIR / "users_log_transformed.parquet")
merchants = pd.read_parquet(DATA_INTERIM_DIR / "merchants_binned.parquet")

# %%
df = transactions.merge(users, on="user_id").merge(merchants, on="merchant_id")

# %%
print("Initial shape:", df.shape)
# Out:
# Initial shape: (500000, 33)

# %%
df.head()
# Out:
#   transaction_id           timestamp user_id merchant_id  amount   channel  \
# 0       TX000000 2022-06-17 23:28:00  U14804       M0314  130.03  in-store
# 1       TX000001 2022-01-04 15:39:00  U16634       M0675  132.00    online
# 2       TX000002 2022-09-09 21:58:00  U18005       M0479    8.65    online
# 3       TX000003 2023-11-20 06:40:00  U13690       M0538   19.82    mobile
# 4       TX000004 2022-04-28 08:08:00  U04642       M0128  101.92  in-store
#
#   currency   device payment_method  is_international  ...     category  \
# 0      EUR  Android     debit_card                 1  ...       travel
# 1      EUR  Android     debit_card                 1  ...  electronics
# 2      EUR  Android    credit_card                 1  ...       gaming
# 3      EUR      iOS    credit_card                 0  ...  electronics
# 4      EUR  Android    credit_card                 1  ...       gaming
#
#    country_y  trust_score  number_of_alerts_last_6_months  \
# 0     France     0.581711                               3
# 1    Germany     0.568933                               2
# 2    Denmark     0.608070                               5
# 3   Portugal     0.592656                               4
# 4      Spain     0.450223                               4
#
#   avg_transaction_amount account_age_months has_fraud_history  \
# 0                  74.97                 23                 1
# 1                  56.92                 23                 0
# 2                  98.93                 75                 0
# 3                  21.60                 82                 0
# 4                  60.61                 82                 0
#
#   log_avg_transaction_amount alerts_binned  account_age_group
# 0                   4.330339           1-3                Mid
# 1                   4.059063           1-3                Mid
# 2                   4.604470            4+        Established
# 3                   3.117950            4+        Established
# 4                   4.120824            4+        Established
#
# [5 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['transaction_id', 'timestamp', 'user_id', 'merchant_id', 'amount',
#        'channel', 'currency', 'device', 'payment_method', 'is_international',
#        'session_length_seconds', 'is_first_time_merchant', 'is_fraud', 'age',
#        'sex', 'education', 'primary_source_of_income', 'country_x',
#        'signup_date', 'risk_score', 'account_age_days',
#        'log_monthly_installments', 'log_monthly_expenses', 'category',
#        'country_y', 'trust_score', 'number_of_alerts_last_6_months',
#        'avg_transaction_amount', 'account_age_months', 'has_fraud_history',
#        'log_avg_transaction_amount', 'alerts_binned', 'account_age_group'],
#       dtype='object')

# %%
df.describe()
# Out:
#                            timestamp         amount  is_international  \
# count                         500000  500000.000000     500000.000000
# mean   2022-12-31 16:45:04.497720576      49.915662          0.928662
# min              2022-01-01 00:06:00       0.000000          0.000000
# 25%              2022-07-01 11:03:45      14.370000          1.000000
# 50%              2022-12-31 20:08:30      34.560000          1.000000
# 75%              2023-07-02 08:45:15      69.172500          1.000000
# max              2023-12-31 23:57:00     714.860000          1.000000
# std                              NaN      49.990657          0.257389
#
#        session_length_seconds  is_first_time_merchant       is_fraud  \
# count           500000.000000           500000.000000  500000.000000
# mean               614.987182                0.501248       0.084822
# min                 30.000000                0.000000       0.000000
# 25%                323.000000                0.000000       0.000000
# 50%                614.000000                1.000000       0.000000
# 75%                907.000000                1.000000       0.000000
# max               1200.000000                1.000000       1.000000
# std                338.091496                0.499999       0.278617
#
#                  age                    signup_date     risk_score  \
# count  500000.000000                         500000  500000.000000
# mean       45.951568  2022-10-06 13:27:43.660799744       0.501592
# min        18.000000            2020-04-21 00:00:00       0.000000
# 25%        32.000000            2021-07-09 00:00:00       0.398761
# 50%        46.000000            2022-10-08 00:00:00       0.500496
# 75%        60.000000            2023-12-29 00:00:00       0.603615
# max        74.000000            2025-03-22 00:00:00       1.000000
# std        16.525405                            NaN       0.149917
#
#        account_age_days  log_monthly_installments  log_monthly_expenses  \
# count     500000.000000             500000.000000         500000.000000
# mean         451.439078                  5.154037              6.512901
# min         -446.000000                  0.009950              0.039221
# 25%            3.000000                  4.482211              5.871160
# 50%          450.000000                  5.339123              6.716825
# 75%          906.000000                  6.037871              7.409403
# max         1350.000000                  8.060445              9.305226
# std          519.505291                  1.224402              1.258722
#
#          trust_score  number_of_alerts_last_6_months  avg_transaction_amount  \
# count  500000.000000                   500000.000000           500000.000000
# mean        0.682945                        3.056854               81.851645
# min         0.000000                        0.000000                0.120000
# 25%         0.546098                        2.000000               24.720000
# 50%         0.697761                        3.000000               58.290000
# 75%         0.826846                        4.000000              117.190000
# max         1.000000                        9.000000              709.040000
# std         0.194412                        1.722031               79.139077
#
#        account_age_months  has_fraud_history  log_avg_transaction_amount
# count       500000.000000      500000.000000               500000.000000
# mean            61.546824           0.520824                    3.898029
# min              6.000000           0.000000                    0.113329
# 25%             32.000000           0.000000                    3.247269
# 50%             61.000000           1.000000                    4.082441
# 75%             92.000000           1.000000                    4.772293
# max            119.000000           1.000000                    6.565321
# std             33.427673           0.499567                    1.165481

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 33 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   transaction_id                  500000 non-null  object
#  1   timestamp                       500000 non-null  datetime64[ns]
#  2   user_id                         500000 non-null  object
#  3   merchant_id                     500000 non-null  object
#  4   amount                          500000 non-null  float64
#  5   channel                         500000 non-null  object
#  6   currency                        500000 non-null  object
#  7   device                          500000 non-null  object
#  8   payment_method                  500000 non-null  object
#  9   is_international                500000 non-null  int64
#  10  session_length_seconds          500000 non-null  int64
#  11  is_first_time_merchant          500000 non-null  int64
#  12  is_fraud                        500000 non-null  int64
#  13  age                             500000 non-null  int64
#  14  sex                             500000 non-null  object
#  15  education                       500000 non-null  object
#  16  primary_source_of_income        500000 non-null  object
#  17  country_x                       500000 non-null  object
#  18  signup_date                     500000 non-null  datetime64[ns]
#  19  risk_score                      500000 non-null  float64
#  20  account_age_days                500000 non-null  int64
#  21  log_monthly_installments        500000 non-null  float64
#  22  log_monthly_expenses            500000 non-null  float64
#  23  category                        500000 non-null  category
#  24  country_y                       500000 non-null  category
#  25  trust_score                     500000 non-null  float64
#  26  number_of_alerts_last_6_months  500000 non-null  int64
#  27  avg_transaction_amount          500000 non-null  float64
#  28  account_age_months              500000 non-null  int64
#  29  has_fraud_history               500000 non-null  int64
#  30  log_avg_transaction_amount      500000 non-null  float64
#  31  alerts_binned                   500000 non-null  object
#  32  account_age_group               500000 non-null  object
# dtypes: category(2), datetime64[ns](2), float64(7), int64(9), object(13)
# memory usage: 119.2+ MB

# %%
categorical_cols = [
    "channel", "currency", "device", "payment_method", "sex",
    "education", "primary_source_of_income", "alerts_binned", "account_age_group"
]

for col in categorical_cols:
    df[col] = df[col].astype("category")

df[categorical_cols].dtypes
# Out:
# channel                     category
# currency                    category
# device                      category
# payment_method              category
# sex                         category
# education                   category
# primary_source_of_income    category
# alerts_binned               category
# account_age_group           category
# dtype: object

# %%
# One-Hot Encoding
df_encoded = pd.get_dummies(df, columns=[
    "channel", "currency", "device", "payment_method", "sex",
    "education", "primary_source_of_income", "alerts_binned", "account_age_group"
], drop_first=True)

print("Shape after one-hot encoding:", df_encoded.shape)
df_encoded.head()
# Out:
# Shape after one-hot encoding: (500000, 46)
#   transaction_id           timestamp user_id merchant_id  amount  \
# 0       TX000000 2022-06-17 23:28:00  U14804       M0314  130.03
# 1       TX000001 2022-01-04 15:39:00  U16634       M0675  132.00
# 2       TX000002 2022-09-09 21:58:00  U18005       M0479    8.65
# 3       TX000003 2023-11-20 06:40:00  U13690       M0538   19.82
# 4       TX000004 2022-04-28 08:08:00  U04642       M0128  101.92
#
#    is_international  session_length_seconds  is_first_time_merchant  is_fraud  \
# 0                 1                     145                       0         0
# 1                 1                      32                       1         0
# 2                 1                     604                       1         0
# 3                 0                    1031                       1         0
# 4                 1                     330                       0         0
#
#    age  ... education_PhD primary_source_of_income_Employment  \
# 0   23  ...         False                               False
# 1   53  ...          True                               False
# 2   58  ...         False                               False
# 3   59  ...         False                                True
# 4   28  ...          True                               False
#
#    primary_source_of_income_Retirement  primary_source_of_income_Savings  \
# 0                                False                              True
# 1                                False                             False
# 2                                False                             False
# 3                                False                             False
# 4                                False                             False
#
#    primary_source_of_income_Student Aid  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
#
#    primary_source_of_income_Unemployment alerts_binned_1-3 alerts_binned_4+  \
# 0                                  False              True            False
# 1                                  False              True            False
# 2                                  False             False             True
# 3                                  False             False             True
# 4                                   True             False             True
#
#    account_age_group_Mid  account_age_group_New
# 0                   True                  False
# 1                   True                  False
# 2                  False                  False
# 3                  False                  False
# 4                  False                  False
#
# [5 rows x 46 columns]

# %%
 print(df_encoded.columns[-10:])
# Out:
# Index(['education_PhD', 'primary_source_of_income_Employment',
#        'primary_source_of_income_Retirement',
#        'primary_source_of_income_Savings',
#        'primary_source_of_income_Student Aid',
#        'primary_source_of_income_Unemployment', 'alerts_binned_1-3',
#        'alerts_binned_4+', 'account_age_group_Mid', 'account_age_group_New'],
#       dtype='object')

# %%
numeric_cols = [
    "amount", "session_length_seconds", "age", "risk_score",
    "account_age_days", "log_monthly_installments", "log_monthly_expenses",
    "trust_score", "number_of_alerts_last_6_months", "avg_transaction_amount",
    "account_age_months", "log_avg_transaction_amount"
]

scaler = StandardScaler()

# Skalowanie
df_encoded[numeric_cols] = scaler.fit_transform(df_encoded[numeric_cols])

df_encoded[numeric_cols].describe()
# Out:
#              amount  session_length_seconds           age    risk_score  \
# count  5.000000e+05            5.000000e+05  5.000000e+05  5.000000e+05
# mean   8.777334e-17            1.131397e-16 -1.078746e-16  6.262084e-16
# std    1.000001e+00            1.000001e+00  1.000001e+00  1.000001e+00
# min   -9.985008e-01           -1.730265e+00 -1.691432e+00 -3.345797e+00
# 25%   -7.110468e-01           -8.636345e-01 -8.442505e-01 -6.859230e-01
# 50%   -3.071710e-01           -2.919869e-03  2.930763e-03 -7.315117e-03
# 75%    3.852091e-01            8.637103e-01  8.501120e-01  6.805316e-01
# max    1.330139e+01            1.730340e+00  1.697293e+00  3.324556e+00
#
#        account_age_days  log_monthly_installments  log_monthly_expenses  \
# count      5.000000e+05              5.000000e+05          5.000000e+05
# mean       8.665069e-18             -4.519478e-16          9.915766e-16
# std        1.000001e+00              1.000001e+00          1.000001e+00
# min       -1.727490e+00             -4.201309e+00         -5.143062e+00
# 25%       -8.632049e-01             -5.486977e-01         -5.098359e-01
# 50%       -2.770096e-03              1.511645e-01          1.620089e-01
# 75%        8.749889e-01              7.218497e-01          7.122325e-01
# max        1.729649e+00              2.373738e+00          2.218383e+00
#
#         trust_score  number_of_alerts_last_6_months  avg_transaction_amount  \
# count  5.000000e+05                    5.000000e+05            5.000000e+05
# mean   8.799859e-16                    2.137490e-17           -3.187992e-16
# std    1.000001e+00                    1.000001e+00            1.000001e+00
# min   -3.512875e+00                   -1.775146e+00           -1.032761e+00
# 25%   -7.039029e-01                   -6.137258e-01           -7.219152e-01
# 50%    7.620972e-02                   -3.301569e-02           -2.977248e-01
# 75%    7.401876e-01                    5.476944e-01            4.465353e-01
# max    1.630844e+00                    3.451245e+00            7.925149e+00
#
#        account_age_months  log_avg_transaction_amount
# count        5.000000e+05                5.000000e+05
# mean        -2.053469e-17               -7.436611e-16
# std          1.000001e+00                1.000001e+00
# min         -1.661703e+00               -3.247333e+00
# 25%         -8.839040e-01               -5.583626e-01
# 50%         -1.635844e-02                1.582282e-01
# 75%          9.110178e-01                7.501329e-01
# max          1.718733e+00                2.288579e+00

# %%
drop_cols = [
    "transaction_id", "timestamp", "user_id", "merchant_id",
    "channel", "currency", "device", "payment_method", "sex", "education",
    "primary_source_of_income", "alerts_binned", "account_age_group",
    "signup_date", "country_x", "country_y", "category"
]

df_encoded = df_encoded.copy()
df_encoded[df.columns] = df[df.columns]
df_model = df_encoded.drop(columns=[col for col in drop_cols if col in df_encoded.columns])



df_model.to_parquet(DATA_PROCESSED_DIR / "df_model_ready.parquet", index=False)

print(f"Final shape: {df_model.shape}")
# Out:
# Final shape: (500000, 38)
